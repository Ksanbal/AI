# %% [markdown]
# - 지도상에 정보를 알려주는 기법
# - 구글지도에서 가져온다
# - 지도에 마크를 찍을때 마크 디자인도 바꿀수 있다
# - vega로 vincent를 지원한다.

# %%
# !pip install folium -U
# Out:
# Requirement already up-to-date: folium in /anaconda3/lib/python3.7/site-packages (0.9.1)
# Requirement already satisfied, skipping upgrade: requests in /anaconda3/lib/python3.7/site-packages (from folium) (2.21.0)
# Requirement already satisfied, skipping upgrade: branca>=0.3.0 in /anaconda3/lib/python3.7/site-packages (from folium) (0.3.1)
# Requirement already satisfied, skipping upgrade: jinja2>=2.9 in /anaconda3/lib/python3.7/site-packages (from folium) (2.10)
# Requirement already satisfied, skipping upgrade: numpy in /anaconda3/lib/python3.7/site-packages (from folium) (1.16.2)
# Requirement already satisfied, skipping upgrade: idna<2.9,>=2.5 in /anaconda3/lib/python3.7/site-packages (from requests->folium) (2.8)
# Requirement already satisfied, skipping upgrade: certifi>=2017.4.17 in /anaconda3/lib/python3.7/site-packages (from requests->folium) (2019.3.9)
# Requirement already satisfied, skipping upgrade: chardet<3.1.0,>=3.0.2 in /anaconda3/lib/python3.7/site-packages (from requests->folium) (3.0.4)
# Requirement already satisfied, skipping upgrade: urllib3<1.25,>=1.21.1 in /anaconda3/lib/python3.7/site-packages (from requests->folium) (1.24.1)
# Requirement already satisfied, skipping upgrade: six in /anaconda3/lib/python3.7/site-packages (from branca>=0.3.0->folium) (1.12.0)
# Requirement already satisfied, skipping upgrade: MarkupSafe>=0.23 in /anaconda3/lib/python3.7/site-packages (from jinja2>=2.9->folium) (1.1.1)

# %%
dir(folium)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-1a59a5bea064> in <module>
# ----> 1 dir(folium)
#
# NameError: name 'folium' is not defined

# %%
import folium
m = folium.Map(location=[37.5665, 126.9780], max_zoom=100, zoom_start=15) #위도,경도,최대줌,시작줌
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
m2 = folium.Map( location=[37.5665, 126.9780], tiles='Stamen Toner') #지도 옵션

# %%
m2
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
m3 = folium.Map( location=[37.5665, 126.9780], tiles='Stamen Terrain')

folium.Marker([37.5248, 126.9375], popup='<i>Mt. Hood Meadows</i>', icon=folium.Icon(icon='cloud')).add_to(m3)
folium.Marker([37.5311, 126.9113], popup='<b>Timberline Lodge</b>').add_to(m3)

# %%
m3
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
m4 = folium.Map( location=[37.5665, 126.9780], tiles='Stamen Toner')
folium.Circle(radius=100, #큰 범위 표시
location= [37.5248, 126.9375],
popup='The Waterfront', 
color='crimson', 
fill=False, 
).add_to(m4)

folium.CircleMarker( #작은 점 표시
location=[37.5311, 126.9113], 
radius=50, 
popup='Laurelhurst Park', 
color='#3186cc', 
fill=True, 
fill_color='#3186cc' 
).add_to(m4)
m4
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
m5 = folium.Map( location=[37.5665, 126.9780], tiles='Stamen Toner')
m5.add_child(folium.LatLngPopup()) # 좌표값을 알려준다.
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
#우리집 좌표
mhome = folium.Map(location=[37.4885, 127.0078], max_zoom=100, zoom_start=15) #위도,경도,최대줌,시작줌
mhome
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
#마커를 찍을 수 있다.
m6 = folium.Map( location=[37.5665, 126.9780], tiles='Stamen Terrain') 
m6.add_child(folium.ClickForMarker(popup="ClickPoint"))
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# 다각형을 찍는 기법
m7 = folium.Map( location=[37.5665, 126.9780], tiles='Stamen Terrain') 

folium.RegularPolygonMarker(
    [37.5665, 126.9780],
    popup='polygon1',
    fill_color='#132b5e',
    number_of_sides=3,
    radius=5
    ).add_to(m7)
folium.RegularPolygonMarker(
    [37.4665, 126.9780],
    popup='polygon2',
    fill_color='#45647d',
    number_of_sides=4,
    radius=10
    ).add_to(m7)
folium.RegularPolygonMarker(
    [37.5665, 126.8780],
    popup='polygon3',
    fill_color='#769d96',
    number_of_sides=6,
    radius=15
    ).add_to(m7)
folium.RegularPolygonMarker(
    [37.4665, 126.8780],
    popup='polygon4',
    fill_color='#769d96',
    number_of_sides=8,
    radius=20
    ).add_to(m7)
m7
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
import pandas as pd
import random

#Iterable
list_data = [10, 20, 30, 20, 15, 30, 45]

#Dicts of iterables
cat_1 = ['y1', 'y2', 'y3', 'y4']
index_1 = range(0, 21, 1)
multi_iter1 = {'index': index_1}
for cat in cat_1:
    multi_iter1[cat] = [random.randint(10, 100) for x in index_1]

cat_2 = ['y' + str(x) for x in range(0, 10, 1)]
index_2 = range(1, 21, 1)
multi_iter2 = {'index': index_2}
for cat in cat_2:
    multi_iter2[cat] = [random.randint(10, 100) for x in index_2]

# %%
# !pip install vincent
# Out:
# Requirement already satisfied: vincent in /anaconda3/lib/python3.7/site-packages (0.4.4)
# Requirement already satisfied: pandas in /anaconda3/lib/python3.7/site-packages (from vincent) (0.24.2)
# Requirement already satisfied: python-dateutil>=2.5.0 in /anaconda3/lib/python3.7/site-packages (from pandas->vincent) (2.8.0)
# Requirement already satisfied: numpy>=1.12.0 in /anaconda3/lib/python3.7/site-packages (from pandas->vincent) (1.16.2)
# Requirement already satisfied: pytz>=2011k in /anaconda3/lib/python3.7/site-packages (from pandas->vincent) (2018.9)
# Requirement already satisfied: six>=1.5 in /anaconda3/lib/python3.7/site-packages (from python-dateutil>=2.5.0->pandas->vincent) (1.12.0)

# %% [markdown]
# - vincent.그래프이름

# %%
import vincent
bar = vincent.Bar(multi_iter1['y1'])
bar.axis_titles(x='Index', y='Value')
bar.to_json('asset/vis1.json')

# %%
line = vincent.Line(multi_iter1, iter_idx='index')
line.axis_titles(x='Index', y='Value')
line.legend(title='Categories')
line.to_json('asset/vis2.json')

# %%
scatter = vincent.Scatter(multi_iter2, iter_idx='index')
scatter.axis_titles(x='Index', y='Data Value')
scatter.legend(title='Categories')
scatter.colors(brew='Set3')
scatter.to_json('asset/vis3.json')

# %%
area = vincent.Area(list_data)
area.to_json('asset/vis4.json')

# %%
import json
m8 = folium.Map( location=[37.5665, 126.9780], tiles='Stamen Terrain') 

folium.RegularPolygonMarker(
    [37.5665, 126.9780],
    fill_color='#132b5e',
    radius=5,
    popup=folium.Popup(max_width=450).add_child(
        folium.Vega(json.load(open('vis1.json')), width=450, height=250))
    ).add_to(m8)
folium.RegularPolygonMarker(
    [37.4665, 126.9780],
    fill_color='#45647d',
    radius=10,
    popup=folium.Popup(max_width=450).add_child(
        folium.Vega(json.load(open('vis2.json')), width=450, height=250))
    ).add_to(m8)
folium.RegularPolygonMarker(
    [37.5665, 126.8780],
    fill_color='#769d96',
    radius=15,
    popup=folium.Popup(max_width=450).add_child(
        folium.Vega(json.load(open('vis3.json')), width=450, height=250))
    ).add_to(m8)
folium.RegularPolygonMarker(
    [37.4665, 126.8780],
    fill_color='#769d96',
    radius=20,
    popup=folium.Popup(max_width=450).add_child(
        folium.Vega(json.load(open('vis4.json')), width=450, height=250))
    ).add_to(m8)
m8
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ---

# %% [markdown]
# ## - 단계구분도

# %%
seoul_topo_json = open('asset/seoul_municipalities_topo_simple.json', encoding='utf8')
seoul_topo_json = json.load(seoul_topo_json)

seoul_geo_json = open('asset/seoul_municipalities_geo_simple.json',encoding='utf-8')
seoul_geo_json = json.load(seoul_geo_json)

# %%
m9 = folium.Map( location=[37.5665, 126.9780], tiles='Mapbox Bright') 

folium.GeoJson(seoul_geo_json,name='geojson').add_to(m9)

folium.TopoJson(seoul_topo_json,"objects.seoul_municipalities_geo",name='topojson').add_to(m9)

folium.LayerControl().add_to(m9)
m9
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
seoul_topo_json['objects']['seoul_municipalities_geo']['geometries']
# Out:
# [{'arcs': [[0, 1, 2]],
#   'type': 'Polygon',
#   'properties': {'code': '11250',
#    'name': '강동구',
#    'name_eng': 'Gangdong-gu',
#    'base_year': '2013',
#    'style': {}}},
#  {'arcs': [[3, -2, 4, 5]],
#   'type': 'Polygon',
#   'properties': {'code': '11240',
#    'name': '송파구',
#    'name_eng': 'Songpa-gu',
#    'base_year': '2013',
#    'style': {}}},
#  {'arcs': [[6, -6, 7, 8, 9, 10]],
#   'type': 'Polygon',
#   'properties': {'code': '11230',
#    'name': '강남구',
#    'name_eng': 'Gangnam-gu',
#    'base_year': '2013',
#    'style': {}}},
#  {'arcs': [[-9, 11, 12, 13, 14]],
#   'type': 'Polygon',
#   'properties': {'code': '11220',
#    'name': '서초구',
#    'name_eng': 'Seocho-gu',
#    'base_year': '2013',
#    'style': {}}},
#  {'arcs': [[-13, 15, 16, 17, 18]],
#   'type': 'Polygon',
#   'properties': {'code': '11210',
#    'name': '관악구',
#    'name_eng': 'Gwanak-gu',
#    'base_year': '2013',
#    'style': {}}},
#  {'arcs': [[-14, -19, 19, 20]],
#   'type': 'Polygon',
#   'properties': {'code': '11200',
#    'name': '동작구',
#    'name_eng': 'Dongjak-gu',
#    'base_year': '2013',
#    'style': {}}},
#  {'arcs': [[21, 22, -20, 23, 24, 25]],
#   'type': 'Polygon',
#   'properties': {'code': '11190',
#    'name': '영등포구',
#    'name_eng': 'Yeongdeungpo-gu',
#    'base_year': '2013',
#    'style': {}}},
#  {'arcs': [[-17, 26, 27]],
#   'type': 'Polygon',
#   'properties': {'code': '11180',
#    'name': '금천구',
#    'name_eng': 'Geumcheon-gu',
#    'base_year': '2013',
#    'style': {}}},
#  {'arcs': [[28, -24, -18, -28, 29]],
#   'type': 'Polygon',
#   'properties': {'code': '11170',
#    'name': '구로구',
#    'name_eng': 'Guro-gu',
#    'base_year': '2013',
#    'style': {}}},
#  {'arcs': [[30, -26, 31, 32]],
#   'type': 'Polygon',
#   'properties': {'code': '11160',
#    'name': '강서구',
#    'name_eng': 'Gangseo-gu',
#    'base_year': '2013',
#    'style': {}}},
#  {'arcs': [[-32, -25, -29, 33]],
#   'type': 'Polygon',
#   'properties': {'code': '11150',
#    'name': '양천구',
#    'name_eng': 'Yangcheon-gu',
#    'base_year': '2013',
#    'style': {}}},
#  {'arcs': [[34, 35, 36, -22, -31, 37, 38]],
#   'type': 'Polygon',
#   'properties': {'code': '11140',
#    'name': '마포구',
#    'name_eng': 'Mapo-gu',
#    'base_year': '2013',
#    'style': {}}},
#  {'arcs': [[39, 40, -35, 41]],
#   'type': 'Polygon',
#   'properties': {'code': '11130',
#    'name': '서대문구',
#    'name_eng': 'Seodaemun-gu',
#    'base_year': '2013',
#    'style': {}}},
#  {'arcs': [[42, -42, -39, 43]],
#   'type': 'Polygon',
#   'properties': {'code': '11120',
#    'name': '은평구',
#    'name_eng': 'Eunpyeong-gu',
#    'base_year': '2013',
#    'style': {}}},
#  {'arcs': [[44, 45, 46, 47, 48]],
#   'type': 'Polygon',
#   'properties': {'code': '11110',
#    'name': '노원구',
#    'name_eng': 'Nowon-gu',
#    'base_year': '2013',
#    'style': {}}},
#  {'arcs': [[-48, 49, 50]],
#   'type': 'Polygon',
#   'properties': {'code': '11100',
#    'name': '도봉구',
#    'name_eng': 'Dobong-gu',
#    'base_year': '2013',
#    'style': {}}},
#  {'arcs': [[-50, -47, 51, 52]],
#   'type': 'Polygon',
#   'properties': {'code': '11090',
#    'name': '강북구',
#    'name_eng': 'Gangbuk-gu',
#    'base_year': '2013',
#    'style': {}}},
#  {'arcs': [[53, -52, -46, 54, 55, 56]],
#   'type': 'Polygon',
#   'properties': {'code': '11080',
#    'name': '성북구',
#    'name_eng': 'Seongbuk-gu',
#    'base_year': '2013',
#    'style': {}}},
#  {'arcs': [[-45, 57, 58, 59, -55]],
#   'type': 'Polygon',
#   'properties': {'code': '11070',
#    'name': '중랑구',
#    'name_eng': 'Jungnang-gu',
#    'base_year': '2013',
#    'style': {}}},
#  {'arcs': [[-56, -60, 60, 61, 62]],
#   'type': 'Polygon',
#   'properties': {'code': '11060',
#    'name': '동대문구',
#    'name_eng': 'Dongdaemun-gu',
#    'base_year': '2013',
#    'style': {}}},
#  {'arcs': [[-59, 63, -3, -4, -7, 64, -61]],
#   'type': 'Polygon',
#   'properties': {'code': '11050',
#    'name': '광진구',
#    'name_eng': 'Gwangjin-gu',
#    'base_year': '2013',
#    'style': {}}},
#  {'arcs': [[-62, -65, -11, 65, 66]],
#   'type': 'Polygon',
#   'properties': {'code': '11040',
#    'name': '성동구',
#    'name_eng': 'Seongdong-gu',
#    'base_year': '2013',
#    'style': {}}},
#  {'arcs': [[-66, -10, -15, -21, -23, -37, 67]],
#   'type': 'Polygon',
#   'properties': {'code': '11030',
#    'name': '용산구',
#    'name_eng': 'Yongsan-gu',
#    'base_year': '2013',
#    'style': {}}},
#  {'arcs': [[-67, -68, -36, -41, 68]],
#   'type': 'Polygon',
#   'properties': {'code': '11020',
#    'name': '중구',
#    'name_eng': 'Jung-gu',
#    'base_year': '2013',
#    'style': {}}},
#  {'arcs': [[69, -57, -63, -69, -40, -43]],
#   'type': 'Polygon',
#   'properties': {'code': '11010',
#    'name': '종로구',
#    'name_eng': 'Jongno-gu',
#    'base_year': '2013',
#    'style': {}}}]

# %%
data = pd.DataFrame.from_dict(seoul_geo_json['features']).properties
# data = pd.DataFrame.from_dict(seoul_topo_json['objects']['seoul_municipalities_geo']['geometries']).properties

# %%
keys = data[0].keys()

# %%
for i in keys:
    print(i)
# Out:
# code
# name
# name_eng
# base_year

# %%
data_list = {}
for key in keys:
    temp_list = []
    for inst in data:
        temp_list.append(inst[key])
    data_list[key] = temp_list

# %%
data_list.keys()
# Out:
# dict_keys(['code', 'name', 'name_eng', 'base_year'])

# %%
seoul_df = pd.DataFrame.from_dict(data_list)

# %%
seoul_df
# Out:
#      code  name         name_eng base_year
# 0   11250   강동구      Gangdong-gu      2013
# 1   11240   송파구        Songpa-gu      2013
# 2   11230   강남구       Gangnam-gu      2013
# 3   11220   서초구        Seocho-gu      2013
# 4   11210   관악구        Gwanak-gu      2013
# 5   11200   동작구       Dongjak-gu      2013
# 6   11190  영등포구  Yeongdeungpo-gu      2013
# 7   11180   금천구     Geumcheon-gu      2013
# 8   11170   구로구          Guro-gu      2013
# 9   11160   강서구       Gangseo-gu      2013
# 10  11150   양천구     Yangcheon-gu      2013
# 11  11140   마포구          Mapo-gu      2013
# 12  11130  서대문구     Seodaemun-gu      2013
# 13  11120   은평구     Eunpyeong-gu      2013
# 14  11110   노원구         Nowon-gu      2013
# 15  11100   도봉구        Dobong-gu      2013
# 16  11090   강북구       Gangbuk-gu      2013
# 17  11080   성북구      Seongbuk-gu      2013
# 18  11070   중랑구      Jungnang-gu      2013
# 19  11060  동대문구    Dongdaemun-gu      2013
# 20  11050   광진구      Gwangjin-gu      2013
# 21  11040   성동구     Seongdong-gu      2013
# 22  11030   용산구       Yongsan-gu      2013
# 23  11020    중구          Jung-gu      2013
# 24  11010   종로구        Jongno-gu      2013

# %%
seoul_df.to_csv('seoul_geo_df.csv')

# %%
m10 = folium.Map( location=[37.5665, 126.9780], tiles='Mapbox Bright') 

seoul_geo_df = pd.read_csv('asset/seoul_geo_df.csv')
m10.choropleth(
    geo_data=seoul_geo_json,
    name='choropleth',
    data=seoul_geo_df,
    columns=['name', 'code'],
    key_on='feature.properties.name',
    fill_color='YlGn',
    fill_opacity=0.7,
    line_opacity=0.2,
    legend_name='Seoul_choropleth'
)

# %%
m10
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
